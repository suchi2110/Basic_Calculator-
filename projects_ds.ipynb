# %% [markdown]
# <a href="https://colab.research.google.com/github/suchi2110/Basic_Calculator-/blob/main/projects_ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import opendatasets as od

# %%
# !pip install opendatasets

# %%
url = 'https://drive.google.com/file/d/1dfGerWeWkcyQ9GX9x20rdSGj7WtEpzBB/view?usp=sharing'

# %%
od.download(url)
# Out:
# ...
# 9908290it [00:00, 656260941.48it/s]
# Downloaded and unzipped to  ./developer_survey_2020

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
survey_raw=pd.read_csv('/content/developer_survey_2020/survey_results_public.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
survey_raw
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_raw.head(3)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN             Germany   European Euro
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling
# 2      NaN        NaN            NaN  Russian Federation             NaN
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                    NaN
# 2            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
# ...

# %%
survey_raw.Employment[0]
# Out:
# 'Independent contractor, freelancer, or self-employed'

# %%
survey_raw.Ethnicity[0]
# Out:
# 'White or of European descent'

# %%
survey_raw.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
survey_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
survey_raw.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
selected_cols = ['MainBranch','Hobbyist','Age','Age1stCode','CompFreq','Country','DatabaseWorkedWith',
                 'DevType','EdLevel','Employment','Gender','JobSat','LanguageDesireNextYear',
                'LanguageWorkedWith','NEWLearn','UndergradMajor',
                 'YearsCode','YearsCodePro','WorkWeekHrs','OrgSize','DatabaseDesireNextYear',
                 'NEWOvertime']

# %%
survey_raw

# %%
len(selected_cols)
# Out:
# 22

# %%
survey=survey_raw[selected_cols].copy()

# %%
survey
# Out:
#                                               MainBranch Hobbyist   Age  \
# 0                         I am a developer by profession      Yes   NaN
# 1                         I am a developer by profession       No   NaN
# 2                            I code primarily as a hobby      Yes   NaN
# 3                         I am a developer by profession      Yes  25.0
# 4      I used to be a developer by profession, but no...      Yes  31.0
# ...                                                  ...      ...   ...
# 64456                                                NaN      Yes   NaN
# 64457                                                NaN      Yes   NaN
# 64458                                                NaN      Yes   NaN
# 64459                                                NaN      Yes   NaN
# 64460                                                NaN      Yes   NaN
#
#       Age1stCode CompFreq             Country  \
# 0             13  Monthly             Germany
# ...

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              64162 non-null  object
#  1   Hobbyist                64416 non-null  object
#  2   Age                     45446 non-null  float64
#  3   Age1stCode              57900 non-null  object
#  4   CompFreq                40069 non-null  object
#  5   Country                 64072 non-null  object
#  6   DatabaseWorkedWith      49537 non-null  object
#  7   DevType                 49370 non-null  object
#  8   EdLevel                 57431 non-null  object
#  9   Employment              63854 non-null  object
#  10  Gender                  50557 non-null  object
#  11  JobSat                  45194 non-null  object
#  12  LanguageDesireNextYear  54113 non-null  object
#  13  LanguageWorkedWith      57378 non-null  object
# ...

# %%
survey.YearsCode  #showing object dtype
# Out:
# 0         36
# 1          7
# 2          4
# 3          7
# 4         15
#         ...
# 64456     10
# 64457    NaN
# 64458    NaN
# 64459    NaN
# 64460    NaN
# Name: YearsCode, Length: 64461, dtype: object

# %%
64460-64162
# Out:
# 298

# %%
survey.isna().sum()/len(survey)*100
# Out:
# MainBranch                 0.463846
# Hobbyist                   0.069810
# Age                       29.498456
# Age1stCode                10.178247
# CompFreq                  37.839934
# Country                    0.603466
# DatabaseWorkedWith        23.151983
# DevType                   23.411055
# EdLevel                   10.905819
# Employment                 0.941655
# Gender                    21.569631
# JobSat                    29.889390
# LanguageDesireNextYear    16.053117
# LanguageWorkedWith        10.988039
# NEWLearn                  12.883759
# UndergradMajor            20.890151
# YearsCode                 10.513334
# YearsCodePro              28.097609
# WorkWeekHrs               36.161400
# OrgSize                   31.223531
# DatabaseDesireNextYear    31.633080
# NEWOvertime               32.934643
# dtype: float64

# %%
survey.isnull().sum() #isnull same as isna ????
# Out:
# MainBranch                  299
# Hobbyist                     45
# Age                       19015
# Age1stCode                 6561
# CompFreq                  24392
# Country                     389
# DatabaseWorkedWith        14924
# DevType                   15091
# EdLevel                    7030
# Employment                  607
# Gender                    13904
# JobSat                    19267
# LanguageDesireNextYear    10348
# LanguageWorkedWith         7083
# NEWLearn                   8305
# UndergradMajor            13466
# YearsCode                  6777
# YearsCodePro              18112
# WorkWeekHrs               23310
# OrgSize                   20127
# DatabaseDesireNextYear    20391
# NEWOvertime               21230
# dtype: int64

# %%
survey.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
survey[survey.Age1stCode=='Younger than 5 years']
# Out:
#                            MainBranch Hobbyist   Age            Age1stCode  \
# 209    I am a developer by profession      Yes  34.0  Younger than 5 years
# 372    I am a developer by profession      Yes  40.0  Younger than 5 years
# 534    I am a developer by profession      Yes  36.0  Younger than 5 years
# 566    I am a developer by profession      Yes  36.0  Younger than 5 years
# 634    I am a developer by profession      Yes  28.0  Younger than 5 years
# ...                               ...      ...   ...                   ...
# 64383                             NaN      Yes   1.0  Younger than 5 years
# 64401                             NaN      Yes   NaN  Younger than 5 years
# 64412                             NaN      Yes   NaN  Younger than 5 years
# 64421                             NaN      Yes  17.0  Younger than 5 years
# 64438                             NaN      Yes   NaN  Younger than 5 years
#
#       CompFreq        Country  \
# 209     Yearly  United States
# ...

# %%
survey.YearsCode.unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
survey[survey.YearsCode == 'Less than 1 year']
# Out:
#                                    MainBranch Hobbyist   Age  \
# 28     I am a student who is learning to code      Yes  18.0
# 319    I am a student who is learning to code       No   NaN
# 364               I code primarily as a hobby      Yes  32.0
# 448    I am a student who is learning to code      Yes  20.0
# 559    I am a student who is learning to code      Yes  19.0
# ...                                       ...      ...   ...
# 64412                                     NaN      Yes   NaN
# 64423                                     NaN      Yes   NaN
# 64437                                     NaN      Yes   NaN
# 64438                                     NaN      Yes   NaN
# 64449                                     NaN      Yes   NaN
#
#                  Age1stCode CompFreq        Country  \
# 28                       15      NaN        Ukraine
# 319                      53      NaN  United States
# 364                      32      NaN         Canada
# ...

# %%
survey.YearsCodePro.unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %%
survey['YearsCodePro']=pd.to_numeric(survey['YearsCodePro'],errors = 'coerce')

# %%
survey['YearsCodePro'].unique()
# Out:
# array([27.,  4., nan,  8., 13.,  2.,  7., 20.,  1., 23.,  3., 12., 17.,
#        18., 10., 14., 29.,  6., 28.,  9., 15., 11., 16., 25.,  5., 21.,
#        19., 35., 24., 32., 22., 30., 38., 26., 40., 33., 31., 34., 36.,
#        39., 37., 41., 45., 47., 42., 46., 50., 43., 44., 48., 49.])

# %%
survey[survey['YearsCodePro'] == 'Less than 1 year']
# Out:
# Empty DataFrame
# Columns: [MainBranch, Hobbyist, Age, Age1stCode, CompFreq, Country, DatabaseWorkedWith, DevType, EdLevel, Employment, Gender, JobSat, LanguageDesireNextYear, LanguageWorkedWith, NEWLearn, UndergradMajor, YearsCode, YearsCodePro, WorkWeekHrs, OrgSize, DatabaseDesireNextYear, NEWOvertime]
# Index: []

# %%
survey['YearsCode'] = pd.to_numeric(survey['YearsCode'],errors = 'coerce')
survey['Age1stCode'] = pd.to_numeric(survey['Age1stCode'],errors = 'coerce')

# %%
survey['YearsCode'].unique()
# Out:
# array([36.,  7.,  4., 15.,  6., 17.,  8., 10., 35.,  5., 37., 19.,  9.,
#        22., 30., 23., 20.,  2., nan,  3., 13., 25., 16., 43., 11., 38.,
#        33., 24., 21., 12., 40., 27., 50., 46., 14., 18., 28., 32., 44.,
#        26., 42., 31., 34., 29.,  1., 39., 41., 45., 47., 49., 48.])

# %%
survey['Age1stCode'].unique()
# Out:
# array([13., 19., 15., 18., 16., 14., 12., 20., 42.,  8., 25., 22., 30.,
#        17., 21., 10., 46.,  9.,  7., 11.,  6., nan, 31., 29.,  5., 28.,
#        38., 23., 27., 41., 24., 53., 26., 35., 32., 40., 33., 36., 54.,
#        48., 56., 45., 44., 34., 39., 51., 68., 50., 37., 47., 43., 52.,
#        85., 64., 55., 58., 49., 76., 72., 73., 83., 63.])

# %%
survey.describe()  #only of numericpd.to_numerical
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey[survey['Age'] ==1]
# Out:
#                                    MainBranch Hobbyist  Age  Age1stCode  \
# 12271  I am a student who is learning to code      Yes  1.0        23.0
# 20042          I am a developer by profession      Yes  1.0        20.0
# 25061          I am a developer by profession      Yes  1.0        12.0
# 54687          I am a developer by profession      Yes  1.0         NaN
# 58292          I am a developer by profession      Yes  1.0         NaN
# 64383                                     NaN      Yes  1.0         NaN
#
#       CompFreq        Country  \
# 12271      NaN        Nigeria
# 20042  Monthly      Indonesia
# 25061   Yearly    Netherlands
# 54687  Monthly  United States
# 58292  Monthly      Indonesia
# 64383      NaN      Indonesia
#
#                                       DatabaseWorkedWith  \
# 12271                                                NaN
# 20042                                            MongoDB
# 25061          DynamoDB;Elasticsearch;MongoDB;PostgreSQL
# ...

# %%
survey['Age'] == 1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: Age, Length: 64461, dtype: bool

# %%
#fliter
survey.drop(survey[survey.Age < 18].index,inplace=True)

# %%
survey.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  44246.000000  56291.000000  55636.000000  44080.000000  41092.000000
# mean      31.247679     15.569558     12.949170      8.877019     40.796317
# std        9.370502      5.111732      9.508275      7.761229     17.797846
# min       18.000000      5.000000      1.000000      1.000000      1.000000
# 25%       25.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       36.000000     18.000000     18.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey.drop(survey[survey.Age >  75].index,inplace=True)

# %%
survey.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  44194.000000  56244.000000  55611.000000  44064.000000  41070.000000
# mean      31.179251     15.565536     12.945586      8.874138     40.791240
# std        9.110811      5.108313      9.502255      7.755869     17.785028
# min       18.000000      5.000000      1.000000      1.000000      1.000000
# 25%       25.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       36.000000     18.000000     18.000000     12.000000     44.000000
# max       75.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey[survey['Age1stCode'] == 8]
# Out:
#                            MainBranch Hobbyist   Age  Age1stCode CompFreq  \
# 15     I am a developer by profession      Yes  45.0         8.0  Monthly
# 73     I am a developer by profession      Yes  34.0         8.0  Monthly
# 98     I am a developer by profession      Yes  42.0         8.0   Yearly
# 158    I am a developer by profession      Yes  32.0         8.0   Yearly
# 196    I am a developer by profession      Yes  40.0         8.0   Yearly
# ...                               ...      ...   ...         ...      ...
# 64168                             NaN      Yes  39.0         8.0      NaN
# 64173                             NaN      Yes   NaN         8.0      NaN
# 64217                             NaN      Yes   NaN         8.0      NaN
# 64244                             NaN      Yes  46.0         8.0      NaN
# 64446                             NaN      Yes   NaN         8.0      NaN
#
#               Country                  DatabaseWorkedWith  \
# ...

# %%
survey.Age1stCode.median()
# Out:
# 15.0

# %%
survey[survey.Country == 'India']
# Out:
#                                    MainBranch Hobbyist   Age  Age1stCode  \
# 6              I am a developer by profession      Yes   NaN        18.0
# 21             I am a developer by profession      Yes   NaN        18.0
# 57             I am a developer by profession      Yes   NaN        22.0
# 62     I am a student who is learning to code      Yes  21.0        17.0
# 147            I am a developer by profession      Yes  36.0        31.0
# ...                                       ...      ...   ...         ...
# 64391                                     NaN      Yes   NaN        18.0
# 64398                                     NaN      Yes   NaN         NaN
# 64439                                     NaN      Yes   NaN         NaN
# 64442                                     NaN      Yes   NaN         NaN
# 64452                                     NaN      Yes   NaN         NaN
#
#       CompFreq Country      DatabaseWorkedWith  \
# ...

# %%
survey['Age1stCode'] = survey.loc[survey['Age1stCode'] < 15 , 'Age1stCode'] == 15 #those whose age is less than 15 is replaced 15

# %%
survey.Age1stCode.unique()
# Out:
# array([13., 19., 15., 18., 16., 14., 12., 20., 42.,  8., 25., 22., 30.,
#        17., 21., 10., 46.,  7., 11.,  9.,  6., nan, 31., 29.,  5., 28.,
#        38., 23., 27., 41., 24., 53., 26., 35., 32., 40., 33., 36., 54.,
#        48., 56., 45., 44., 34., 39., 51., 68., 50., 37., 47., 43., 52.,
#        85., 64., 55., 58., 49., 76., 72., 73., 83., 63.])

# %%
def age(value):
  if value < 15:
    return 15
  elif value > 75:
    return 75
  else:
    return value

# %%
survey['Age1stCode'] = survey['Age1stCode'].map(age)

# %%
survey.Age1stCode.unique()
# Out:
# array([15., 19., 18., 16., 20., 42., 25., 22., 30., 17., 21., 46., nan,
#        31., 29., 28., 38., 23., 27., 41., 24., 53., 26., 35., 32., 40.,
#        33., 36., 54., 48., 56., 45., 44., 34., 39., 51., 68., 50., 37.,
#        47., 43., 52., 75., 64., 55., 58., 49., 72., 73., 63.])

# %%
survey.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  44194.000000  56244.000000  55611.000000  44064.000000  41070.000000
# mean      31.179251     17.097877     12.945586      8.874138     40.791240
# std        9.110811      3.767023      9.502255      7.755869     17.785028
# min       18.000000     15.000000      1.000000      1.000000      1.000000
# 25%       25.000000     15.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       36.000000     18.000000     18.000000     12.000000     44.000000
# max       75.000000     75.000000     50.000000     50.000000    475.000000

# %%
survey[survey['Age1stCode'] == 15]
# Out:
#                            MainBranch Hobbyist   Age  Age1stCode CompFreq  \
# 0      I am a developer by profession      Yes   NaN        15.0  Monthly
# 2         I code primarily as a hobby      Yes   NaN        15.0      NaN
# 5      I am a developer by profession       No   NaN        15.0      NaN
# 7      I am a developer by profession      Yes  36.0        15.0   Yearly
# 9      I am a developer by profession      Yes  22.0        15.0   Yearly
# ...                               ...      ...   ...         ...      ...
# 64422                             NaN      Yes  23.0        15.0      NaN
# 64426                             NaN      Yes  22.0        15.0      NaN
# 64432                             NaN      Yes   NaN        15.0      NaN
# 64446                             NaN      Yes   NaN        15.0      NaN
# 64453                             NaN      Yes   NaN        15.0      NaN
#
#                   Country                           DatabaseWorkedWith  \
# ...
